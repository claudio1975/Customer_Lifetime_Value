# %% [markdown]
# # Unsupervised Learning applied to Customer Lifetime Value (CLV)

# %% [markdown]
# ![](https://wilsonprintingusa.com/wp-content/uploads/2015/02/Customer-Lifetime-Value-Wilson-Printing.jpg)

# %% [markdown]
# # Prepare Workspace

# %%
# Upload libraries
from numpy.random import seed
seed(1)
import tensorflow.keras
tensorflow.random.set_seed(2)

# to handle datasets
import numpy as np
import pandas as pd
import datetime

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from pandas.plotting import autocorrelation_plot

# for statistics
import statistics as st 
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# to split data set 
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# to build models
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

# dimensionality reductiion
from sklearn.decomposition import PCA
from sklearn.manifold import Isomap
from sklearn.manifold import TSNE
from keras.layers import Input,Dense
from keras.models import Model

# clustering
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors

# to evaluate models
from sklearn.metrics import mean_squared_error
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('AutoInsurance.csv')

# %% [markdown]
# # Data set Overview

# %%
# Dimensions of data set
print(df.shape)
# Out:
# (9134, 24)

# %%
# List types for each attribute
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB
# None

# %%
# Take a peek at the first rows of the data
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4          3/2/2011         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %% [markdown]
# # Data Cleaning & Handling Variables Activity

# %%
# Change format Date
df_1 = df.copy()
df_1['Effective_Date'] = pd.to_datetime(df_1['Effective To Date'])

# %% [markdown]
# ### Handling Missing Values

# %%
# Check missing values both to numeric features and categorical features 
missing = df_1.isnull().sum()/df_1.shape[0]*100
missing
# Out:
# Customer                         0.0
# State                            0.0
# Customer Lifetime Value          0.0
# Response                         0.0
# Coverage                         0.0
# Education                        0.0
# Effective To Date                0.0
# EmploymentStatus                 0.0
# Gender                           0.0
# Income                           0.0
# Location Code                    0.0
# Marital Status                   0.0
# Monthly Premium Auto             0.0
# Months Since Last Claim          0.0
# Months Since Policy Inception    0.0
# Number of Open Complaints        0.0
# Number of Policies               0.0
# Policy Type                      0.0
# Policy                           0.0
# Renew Offer Type                 0.0
# Sales Channel                    0.0
# Total Claim Amount               0.0
# Vehicle Class                    0.0
# Vehicle Size                     0.0
# Effective_Date                   0.0
# dtype: float64

# %%
# Min Value Effective to Date Policy
df_1['Effective_Date'].min()
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
# Max Value Effective to Date Policy
df_1['Effective_Date'].max()
# Out:
# Timestamp('2011-12-02 00:00:00')

# %%
# End of Year (eoy) of the current Effective to Date
df_1['eoy_Effective_Date'] = pd.to_datetime('2011-12-31')

# %%
# Days missing to the end of the current year from effective to date
df_1['eoy_missing_days'] = (df_1['eoy_Effective_Date'] - df_1['Effective_Date']).dt.days

# %%
# check duplicates
df_1_duplicates = df_1[df_1.duplicated(['Customer'])]

# %%
df_1_duplicates
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size, Effective_Date, eoy_Effective_Date, eoy_missing_days]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_1 = df_1.drop(['Customer','Effective To Date','eoy_Effective_Date'], axis=1)

# %%
# Rename some features for a practical use
df_new = df_1.copy()
df_new = df_new.rename(columns={"Customer Lifetime Value":"Customer_Lifetime_Value","Location Code":"Location_Code","Marital Status":"Marital_Status","Monthly Premium Auto":"Monthly_Premium_Auto","Months Since Last Claim":"Months_Since_Last_Claim",
                           "Months Since Policy Inception":"Months_Since_Policy_Inception","Number of Open Complaints":"Number_of_Open_Complaints","Number of Policies":"Number_of_Policies",
                           "Policy Type":"Policy_Type","Renew Offer Type":"Renew_Offer_Type","Sales Channel":"Sales_Channel","Total Claim Amount":"Total_Claim_Amount",
                           "Vehicle Class":"Vehicle_Class","Vehicle Size":"Vehicle_Size"})

# %% [markdown]
# # Summary Statistics

# %%
# Summarize attribute distributions for data type of variables
obj_cols = [var for var in df_new.columns if df_new[var].dtype=='object']
df_new[obj_cols].describe().T
# Out:
#                  count unique            top  freq
# State             9134      5     California  3150
# Response          9134      2             No  7826
# Coverage          9134      3          Basic  5568
# Education         9134      5       Bachelor  2748
# EmploymentStatus  9134      5       Employed  5698
# Gender            9134      2              F  4658
# Location_Code     9134      3       Suburban  5779
# Marital_Status    9134      3        Married  5298
# Policy_Type       9134      3  Personal Auto  6788
# Policy            9134      9    Personal L3  3426
# Renew_Offer_Type  9134      4         Offer1  3752
# Sales_Channel     9134      4          Agent  3477
# Vehicle_Class     9134      6  Four-Door Car  4621
# Vehicle_Size      9134      3        Medsize  6424

# %%
# Summarize attribute distributions for data type of variables
no_obj_cols = [var for var in df_new.columns if df_new[var].dtype!='object']
df_new[no_obj_cols].describe().T
# Out:
#                                 count          mean           std  \
# Customer_Lifetime_Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly_Premium_Auto           9134.0     93.219291     34.407967
# Months_Since_Last_Claim        9134.0     15.097000     10.073257
# Months_Since_Policy_Inception  9134.0     48.064594     27.905991
# Number_of_Open_Complaints      9134.0      0.384388      0.910384
# Number_of_Policies             9134.0      2.966170      2.390182
# Total_Claim_Amount             9134.0    434.088794    290.500092
# eoy_missing_days               9134.0    276.667068     93.820412
#
#                                        min          25%           50%  \
# Customer_Lifetime_Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly_Premium_Auto             61.000000    68.000000     83.000000
# Months_Since_Last_Claim           0.000000     6.000000     14.000000
# Months_Since_Policy_Inception     0.000000    24.000000     48.000000
# Number_of_Open_Complaints         0.000000     0.000000      0.000000
# Number_of_Policies                1.000000     1.000000      2.000000
# Total_Claim_Amount                0.099007   272.258244    383.945434
# eoy_missing_days                 29.000000   244.000000    315.000000
#
#                                         75%           max
# Customer_Lifetime_Value         8962.167041  83325.381190
# Income                         62320.000000  99981.000000
# Monthly_Premium_Auto             109.000000    298.000000
# Months_Since_Last_Claim           23.000000     35.000000
# Months_Since_Policy_Inception     71.000000     99.000000
# Number_of_Open_Complaints          0.000000      5.000000
# Number_of_Policies                 4.000000      9.000000
# Total_Claim_Amount               547.514839   2893.239678
# eoy_missing_days                 340.000000    364.000000

# %%
date_cols = [cname for cname in df_new.columns if 
             df_new[cname].dtype in ['datetime64[ns]']]
date = df_new[date_cols]
date.describe().T
# Out:
#                count unique        top freq      first       last
# Effective_Date  9134     59 2011-10-01  195 2011-01-01 2011-12-02

# %%
# Split data set between target variable and features
X_full = df_new.copy()
y = X_full.Customer_Lifetime_Value
X_full.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)

# %%
# Select numerical columns
numerical_cols = [cname for cname in X_full.columns if 
                X_full[cname].dtype in ['float64','int64']]

# %%
# Subset with numerical features
num = X_full[numerical_cols]
num.columns
# Out:
# Index(['Income', 'Monthly_Premium_Auto', 'Months_Since_Last_Claim',
#        'Months_Since_Policy_Inception', 'Number_of_Open_Complaints',
#        'Number_of_Policies', 'Total_Claim_Amount', 'eoy_missing_days'],
#       dtype='object')

# %%
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X_full.columns if
                    X_full[cname].nunique() <= 15 and 
                    X_full[cname].dtype == "object"]

# %%
# Subset with categorical features
cat = X_full[categorical_cols]
cat.columns
# Out:
# Index(['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus',
#        'Gender', 'Location_Code', 'Marital_Status', 'Policy_Type', 'Policy',
#        'Renew_Offer_Type', 'Sales_Channel', 'Vehicle_Class', 'Vehicle_Size'],
#       dtype='object')

# %% [markdown]
# # Pre-Processing on all data set

# %% [markdown]
# ### One-Hot Encoding into k-1 dummy variables

# %%
# Encode the categorical data 
dummy_cat = pd.concat([pd.get_dummies(cat.State, prefix='State',drop_first=True), 
                       pd.get_dummies(cat.Coverage, prefix= 'Coverage', drop_first=True), 
                       pd.get_dummies(cat.Response, prefix= 'Response', drop_first=True),
                       pd.get_dummies(cat.Education, prefix='Education',drop_first=True),
                       pd.get_dummies(cat.EmploymentStatus, prefix='EmploymentStatus',drop_first=True),
                       pd.get_dummies(cat.Gender, prefix='Gender',drop_first=True),
                       pd.get_dummies(cat.Location_Code, prefix='Location_Code',drop_first=True),
                       pd.get_dummies(cat.Marital_Status, prefix='Marital_Status',drop_first=True),
                       pd.get_dummies(cat.Policy_Type, prefix='Policy_Type',drop_first=True),
                       pd.get_dummies(cat.Policy, prefix='Policy',drop_first=True),
                       pd.get_dummies(cat.Renew_Offer_Type, prefix='Renew_Offer_Type',drop_first=True),
                       pd.get_dummies(cat.Sales_Channel, prefix='Sales_Channel',drop_first=True),
                       pd.get_dummies(cat.Vehicle_Size, prefix='Vehicle_Size',drop_first=True),
                       pd.get_dummies(cat.Vehicle_Class, prefix='Vehicle_Class',drop_first=True)], axis=1)
dummy_cat = dummy_cat.astype(int)

# %%
# Grasp all
X_all = pd.concat([dummy_cat, num], axis=1)

# %%
X_all.shape
# Out:
# (9134, 51)

# %% [markdown]
# ### Zero/Close Zero Variance Predictors

# %%
# Find features with variance equal zero or lower than 0.05
to_drop = [col for col in X_all.columns if np.var(X_all[col]) < 0.05]
to_drop
# Out:
# ['Education_Doctor',
#  'EmploymentStatus_Medical Leave',
#  'EmploymentStatus_Retired',
#  'Policy_Type_Special Auto',
#  'Policy_Special L1',
#  'Policy_Special L2',
#  'Policy_Special L3',
#  'Vehicle_Class_Luxury Car',
#  'Vehicle_Class_Luxury SUV']

# %%
# Drop features 
X_all_v = X_all.drop(X_all[to_drop], axis=1)

# %%
# Look at the new data set
X_all_v.shape
# Out:
# (9134, 42)

# %%
# Normalization of data
scaling = MinMaxScaler()
X_all_sc = scaling.fit_transform(X_all_v)

# %% [markdown]
# # PCA Modeling & Prediction

# %%
components=5
pca = PCA(n_components=components, random_state=0)
pca_X_all_sc = pca.fit_transform(X_all_sc)
pca_df = pd.DataFrame(data = pca_X_all_sc, columns = ['pca'+str(i) for i in range(pca_X_all_sc.shape[1])])
all_pca = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], pca_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_pca[all_pca['Effective_Date'] <= '2011-09-30']
test = all_pca[all_pca['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_pca': rmse_train,
        'rmse_test_pca': rmse_test
    }
score.append(score_dict)
score_3M_pca_1 = pd.DataFrame(score, columns = ['features','rmse_train_pca', 'rmse_test_pca'])

# %%
components=10
pca = PCA(n_components=components, random_state=0)
pca_X_all_sc = pca.fit_transform(X_all_sc)
pca_df = pd.DataFrame(data = pca_X_all_sc, columns = ['pca'+str(i) for i in range(pca_X_all_sc.shape[1])])
all_pca = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], pca_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_pca[all_pca['Effective_Date'] <= '2011-09-30']
test = all_pca[all_pca['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_pca': rmse_train,
        'rmse_test_pca': rmse_test
    }
score.append(score_dict)
score_3M_pca_2 = pd.DataFrame(score, columns = ['features','rmse_train_pca', 'rmse_test_pca'])

# %%
components=15
pca = PCA(n_components=components, random_state=0)
pca_X_all_sc = pca.fit_transform(X_all_sc)
pca_df = pd.DataFrame(data = pca_X_all_sc, columns = ['pca'+str(i) for i in range(pca_X_all_sc.shape[1])])
all_pca = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], pca_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_pca[all_pca['Effective_Date'] <= '2011-09-30']
test = all_pca[all_pca['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_pca': rmse_train,
        'rmse_test_pca': rmse_test
    }
score.append(score_dict)
score_3M_pca_3 = pd.DataFrame(score, columns = ['features','rmse_train_pca', 'rmse_test_pca'])

# %%
components=20
pca = PCA(n_components=components, random_state=0)
pca_X_all_sc = pca.fit_transform(X_all_sc)
pca_df = pd.DataFrame(data = pca_X_all_sc, columns = ['pca'+str(i) for i in range(pca_X_all_sc.shape[1])])
all_pca = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], pca_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_pca[all_pca['Effective_Date'] <= '2011-09-30']
test = all_pca[all_pca['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_pca': rmse_train,
        'rmse_test_pca': rmse_test
    }
score.append(score_dict)
score_3M_pca_4 = pd.DataFrame(score, columns = ['features','rmse_train_pca', 'rmse_test_pca'])

# %%
components=25
pca = PCA(n_components=components, random_state=0)
pca_X_all_sc = pca.fit_transform(X_all_sc)
pca_df = pd.DataFrame(data = pca_X_all_sc, columns = ['pca'+str(i) for i in range(pca_X_all_sc.shape[1])])
all_pca = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], pca_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_pca[all_pca['Effective_Date'] <= '2011-09-30']
test = all_pca[all_pca['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_pca': rmse_train,
        'rmse_test_pca': rmse_test
    }
score.append(score_dict)
score_3M_pca_5 = pd.DataFrame(score, columns = ['features','rmse_train_pca', 'rmse_test_pca'])

# %%
score_pca = score_3M_pca_1.append(score_3M_pca_2)
score_pca = score_pca.append(score_3M_pca_3)
score_pca = score_pca.append(score_3M_pca_4)
score_pca = score_pca.append(score_3M_pca_5)
score_pca
# Out:
#    features  rmse_train_pca  rmse_test_pca
# 0         5        0.625759       0.663359
# 0        10        0.615976       0.659641
# 0        15        0.585712       0.628892
# 0        20        0.575250       0.626842
# 0        25        0.490460       0.561257

# %% [markdown]
# # Autoencoders Modeling & Prediction

# %%
encoding_dim = 5 
# This is our input 
input_data = Input(shape=(42,)) # 42 is the number of features/columns
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_data)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(42, activation='relu')(encoded)
# This model maps an input to its reconstruction
autoencoder = Model(input_data, decoded)
# create a separate encoder model:
# This model maps an input to its encoded representation
encoder = Model(input_data, encoded)
# create a separate decoder model:
encoded_input = Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))
# Configure the model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
# train the model
autoencoder.fit(X_all_sc,
                X_all_sc,
                epochs=50)
# predict after training
encoded_input = encoder.predict(X_all_sc)
autoencoder_df = pd.DataFrame(data = encoded_input, columns=['autoencoder'+str(i) for i in range(encoded_input.shape[1])])
all_autoencoder = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], autoencoder_df], axis=1)
# Out:
# Epoch 1/50
# 286/286 [==============================] - 0s 718us/step - loss: 0.1753
# Epoch 2/50
# 286/286 [==============================] - 0s 728us/step - loss: 0.1201
# Epoch 3/50
# 286/286 [==============================] - 0s 701us/step - loss: 0.1105
# Epoch 4/50
# 286/286 [==============================] - 0s 837us/step - loss: 0.1068
# Epoch 5/50
# 286/286 [==============================] - 0s 723us/step - loss: 0.1045
# Epoch 6/50
# 286/286 [==============================] - 0s 709us/step - loss: 0.1025
# Epoch 7/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.1012
# Epoch 8/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.1002
# Epoch 9/50
# 286/286 [==============================] - 0s 745us/step - loss: 0.0995
# Epoch 10/50
# 286/286 [==============================] - 0s 698us/step - loss: 0.0990
# Epoch 11/50
# 286/286 [==============================] - 0s 703us/step - loss: 0.0986
# Epoch 12/50
# 286/286 [==============================] - 0s 689us/step - loss: 0.0981
# Epoch 13/50
# 286/286 [==============================] - 0s 684us/step - loss: 0.0977
# Epoch 14/50
# 286/286 [==============================] - 0s 701us/step - loss: 0.0973
# Epoch 15/50
# 286/286 [==============================] - 0s 683us/step - loss: 0.0968
# Epoch 16/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0961
# Epoch 17/50
# 286/286 [==============================] - 0s 706us/step - loss: 0.0953
# Epoch 18/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0945
# Epoch 19/50
# 286/286 [==============================] - 0s 684us/step - loss: 0.0938
# Epoch 20/50
# 286/286 [==============================] - 0s 697us/step - loss: 0.0932
# Epoch 21/50
# 286/286 [==============================] - 0s 689us/step - loss: 0.0926
# Epoch 22/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0921
# Epoch 23/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0917
# Epoch 24/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0913
# Epoch 25/50
# 286/286 [==============================] - 0s 707us/step - loss: 0.0910
# Epoch 26/50
# 286/286 [==============================] - 0s 721us/step - loss: 0.0907
# Epoch 27/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0905
# Epoch 28/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0903
# Epoch 29/50
# 286/286 [==============================] - 0s 722us/step - loss: 0.0901
# Epoch 30/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0900
# Epoch 31/50
# 286/286 [==============================] - 0s 687us/step - loss: 0.0898
# Epoch 32/50
# 286/286 [==============================] - 0s 690us/step - loss: 0.0897
# Epoch 33/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0895
# Epoch 34/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0893
# Epoch 35/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0892
# Epoch 36/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0891
# Epoch 37/50
# 286/286 [==============================] - 0s 692us/step - loss: 0.0890
# Epoch 38/50
# 286/286 [==============================] - 0s 710us/step - loss: 0.0889
# Epoch 39/50
# 286/286 [==============================] - 0s 697us/step - loss: 0.0888
# Epoch 40/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0888
# Epoch 41/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0887
# Epoch 42/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0886
# Epoch 43/50
# 286/286 [==============================] - 0s 692us/step - loss: 0.0885
# Epoch 44/50
# 286/286 [==============================] - 0s 702us/step - loss: 0.0885
# Epoch 45/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0885
# Epoch 46/50
# 286/286 [==============================] - 0s 694us/step - loss: 0.0884
# Epoch 47/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0884
# Epoch 48/50
# 286/286 [==============================] - 0s 698us/step - loss: 0.0884
# Epoch 49/50
# 286/286 [==============================] - 0s 720us/step - loss: 0.0883
# Epoch 50/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0882

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_autoencoder[all_autoencoder['Effective_Date'] <= '2011-09-30']
test = all_autoencoder[all_autoencoder['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': encoding_dim,
        'rmse_train_autoencoder': rmse_train,
        'rmse_test_autoencoder': rmse_test
    }
score.append(score_dict)
score_3M_aut_1 = pd.DataFrame(score, columns = ['features','rmse_train_autoencoder', 'rmse_test_autoencoder'])

# %%
encoding_dim = 10 
# This is our input 
input_data = Input(shape=(42,)) # 42 is the number of features/columns
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_data)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(42, activation='relu')(encoded)
# This model maps an input to its reconstruction
autoencoder = Model(input_data, decoded)
# create a separate encoder model:
# This model maps an input to its encoded representation
encoder = Model(input_data, encoded)
# create a separate decoder model:
encoded_input = Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))
# Configure the model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
# train the model
autoencoder.fit(X_all_sc,
                X_all_sc,
                epochs=50)
# predict after training
encoded_input = encoder.predict(X_all_sc)
autoencoder_df = pd.DataFrame(data = encoded_input, columns=['autoencoder'+str(i) for i in range(encoded_input.shape[1])])
all_autoencoder = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], autoencoder_df], axis=1)
# Out:
# Epoch 1/50
# 286/286 [==============================] - 0s 679us/step - loss: 0.1519
# Epoch 2/50
# 286/286 [==============================] - 0s 682us/step - loss: 0.0975
# Epoch 3/50
# 286/286 [==============================] - 0s 701us/step - loss: 0.0790
# Epoch 4/50
# 286/286 [==============================] - 0s 716us/step - loss: 0.0718
# Epoch 5/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0669
# Epoch 6/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0630
# Epoch 7/50
# 286/286 [==============================] - 0s 687us/step - loss: 0.0603
# Epoch 8/50
# 286/286 [==============================] - 0s 690us/step - loss: 0.0584
# Epoch 9/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0570
# Epoch 10/50
# 286/286 [==============================] - 0s 683us/step - loss: 0.0559
# Epoch 11/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0551
# Epoch 12/50
# 286/286 [==============================] - 0s 679us/step - loss: 0.0544
# Epoch 13/50
# 286/286 [==============================] - 0s 688us/step - loss: 0.0537
# Epoch 14/50
# 286/286 [==============================] - 0s 689us/step - loss: 0.0531
# Epoch 15/50
# 286/286 [==============================] - 0s 682us/step - loss: 0.0525
# Epoch 16/50
# 286/286 [==============================] - 0s 689us/step - loss: 0.0518
# Epoch 17/50
# 286/286 [==============================] - 0s 686us/step - loss: 0.0512
# Epoch 18/50
# 286/286 [==============================] - 0s 694us/step - loss: 0.0507
# Epoch 19/50
# 286/286 [==============================] - 0s 685us/step - loss: 0.0501
# Epoch 20/50
# 286/286 [==============================] - 0s 697us/step - loss: 0.0497
# Epoch 21/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0493
# Epoch 22/50
# 286/286 [==============================] - 0s 685us/step - loss: 0.0488
# Epoch 23/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0485
# Epoch 24/50
# 286/286 [==============================] - 0s 694us/step - loss: 0.0482
# Epoch 25/50
# 286/286 [==============================] - 0s 692us/step - loss: 0.0479
# Epoch 26/50
# 286/286 [==============================] - 0s 684us/step - loss: 0.0477
# Epoch 27/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0475
# Epoch 28/50
# 286/286 [==============================] - 0s 683us/step - loss: 0.0473
# Epoch 29/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0471
# Epoch 30/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0470
# Epoch 31/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0468
# Epoch 32/50
# 286/286 [==============================] - 0s 832us/step - loss: 0.0467
# Epoch 33/50
# 286/286 [==============================] - 0s 771us/step - loss: 0.0465
# Epoch 34/50
# 286/286 [==============================] - 0s 835us/step - loss: 0.0464
# Epoch 35/50
# 286/286 [==============================] - 0s 768us/step - loss: 0.0463
# Epoch 36/50
# 286/286 [==============================] - 0s 698us/step - loss: 0.0462
# Epoch 37/50
# 286/286 [==============================] - 0s 779us/step - loss: 0.0460
# Epoch 38/50
# 286/286 [==============================] - 0s 841us/step - loss: 0.0459
# Epoch 39/50
# 286/286 [==============================] - 0s 704us/step - loss: 0.0457
# Epoch 40/50
# 286/286 [==============================] - 0s 830us/step - loss: 0.0456
# Epoch 41/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0455
# Epoch 42/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0454
# Epoch 43/50
# 286/286 [==============================] - 0s 805us/step - loss: 0.0453
# Epoch 44/50
# 286/286 [==============================] - 0s 814us/step - loss: 0.0452
# Epoch 45/50
# 286/286 [==============================] - 0s 698us/step - loss: 0.0452
# Epoch 46/50
# 286/286 [==============================] - 0s 706us/step - loss: 0.0450
# Epoch 47/50
# 286/286 [==============================] - 0s 706us/step - loss: 0.0450
# Epoch 48/50
# 286/286 [==============================] - 0s 732us/step - loss: 0.0450
# Epoch 49/50
# 286/286 [==============================] - 0s 792us/step - loss: 0.0449
# Epoch 50/50
# 286/286 [==============================] - 0s 703us/step - loss: 0.0448

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_autoencoder[all_autoencoder['Effective_Date'] <= '2011-09-30']
test = all_autoencoder[all_autoencoder['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': encoding_dim,
        'rmse_train_autoencoder': rmse_train,
        'rmse_test_autoencoder': rmse_test
    }
score.append(score_dict)
score_3M_aut_2 = pd.DataFrame(score, columns = ['features','rmse_train_autoencoder', 'rmse_test_autoencoder'])

# %%
encoding_dim = 15
# This is our input 
input_data = Input(shape=(42,)) # 42 is the number of features/columns
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_data)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(42, activation='relu')(encoded)
# This model maps an input to its reconstruction
autoencoder = Model(input_data, decoded)
# create a separate encoder model:
# This model maps an input to its encoded representation
encoder = Model(input_data, encoded)
# create a separate decoder model:
encoded_input = Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))
# Configure the model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
# train the model
autoencoder.fit(X_all_sc,
                X_all_sc,
                epochs=50)
# predict after training
encoded_input = encoder.predict(X_all_sc)
autoencoder_df = pd.DataFrame(data = encoded_input, columns=['autoencoder'+str(i) for i in range(encoded_input.shape[1])])
all_autoencoder = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], autoencoder_df], axis=1)
# Out:
# Epoch 1/50
#   1/286 [..............................] - ETA: 0s - loss: 0.2440WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
# 286/286 [==============================] - 0s 801us/step - loss: 0.1479
# Epoch 2/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0889
# Epoch 3/50
# 286/286 [==============================] - 0s 914us/step - loss: 0.0721
# Epoch 4/50
# 286/286 [==============================] - 0s 854us/step - loss: 0.0612
# Epoch 5/50
# 286/286 [==============================] - 0s 787us/step - loss: 0.0544
# Epoch 6/50
# 286/286 [==============================] - 0s 694us/step - loss: 0.0504
# Epoch 7/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0475
# Epoch 8/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0453
# Epoch 9/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0435
# Epoch 10/50
# 286/286 [==============================] - 0s 715us/step - loss: 0.0422
# Epoch 11/50
# 286/286 [==============================] - 0s 840us/step - loss: 0.0412
# Epoch 12/50
# 286/286 [==============================] - 0s 690us/step - loss: 0.0405
# Epoch 13/50
# 286/286 [==============================] - 0s 726us/step - loss: 0.0400
# Epoch 14/50
# 286/286 [==============================] - 0s 701us/step - loss: 0.0395
# Epoch 15/50
# 286/286 [==============================] - 0s 701us/step - loss: 0.0391
# Epoch 16/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0387
# Epoch 17/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0384
# Epoch 18/50
# 286/286 [==============================] - 0s 712us/step - loss: 0.0381
# Epoch 19/50
# 286/286 [==============================] - 0s 704us/step - loss: 0.0379
# Epoch 20/50
# 286/286 [==============================] - 0s 698us/step - loss: 0.0377
# Epoch 21/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0375
# Epoch 22/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0373
# Epoch 23/50
# 286/286 [==============================] - 0s 712us/step - loss: 0.0371
# Epoch 24/50
# 286/286 [==============================] - 0s 697us/step - loss: 0.0370
# Epoch 25/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0368
# Epoch 26/50
# 286/286 [==============================] - 0s 731us/step - loss: 0.0367
# Epoch 27/50
# 286/286 [==============================] - 0s 888us/step - loss: 0.0366
# Epoch 28/50
# 286/286 [==============================] - 0s 789us/step - loss: 0.0365
# Epoch 29/50
# 286/286 [==============================] - 0s 849us/step - loss: 0.0364
# Epoch 30/50
# 286/286 [==============================] - 0s 858us/step - loss: 0.0363
# Epoch 31/50
# 286/286 [==============================] - 0s 880us/step - loss: 0.0362
# Epoch 32/50
# 286/286 [==============================] - 0s 837us/step - loss: 0.0361
# Epoch 33/50
# 286/286 [==============================] - 0s 896us/step - loss: 0.0360
# Epoch 34/50
# 286/286 [==============================] - 0s 868us/step - loss: 0.0359
# Epoch 35/50
# 286/286 [==============================] - 0s 815us/step - loss: 0.0358
# Epoch 36/50
# 286/286 [==============================] - 0s 780us/step - loss: 0.0357
# Epoch 37/50
# 286/286 [==============================] - 0s 675us/step - loss: 0.0357
# Epoch 38/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0356
# Epoch 39/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0356
# Epoch 40/50
# 286/286 [==============================] - 0s 731us/step - loss: 0.0355
# Epoch 41/50
# 286/286 [==============================] - 0s 849us/step - loss: 0.0355
# Epoch 42/50
# 286/286 [==============================] - 0s 718us/step - loss: 0.0355
# Epoch 43/50
# 286/286 [==============================] - 0s 721us/step - loss: 0.0354
# Epoch 44/50
# 286/286 [==============================] - 0s 759us/step - loss: 0.0354
# Epoch 45/50
# 286/286 [==============================] - 0s 892us/step - loss: 0.0354
# Epoch 46/50
# 286/286 [==============================] - 0s 872us/step - loss: 0.0354
# Epoch 47/50
# 286/286 [==============================] - 0s 737us/step - loss: 0.0353
# Epoch 48/50
# 286/286 [==============================] - 0s 712us/step - loss: 0.0353
# Epoch 49/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0353
# Epoch 50/50
# 286/286 [==============================] - 0s 707us/step - loss: 0.0353

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_autoencoder[all_autoencoder['Effective_Date'] <= '2011-09-30']
test = all_autoencoder[all_autoencoder['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': encoding_dim,
        'rmse_train_autoencoder': rmse_train,
        'rmse_test_autoencoder': rmse_test
    }
score.append(score_dict)
score_3M_aut_3 = pd.DataFrame(score, columns = ['features','rmse_train_autoencoder', 'rmse_test_autoencoder'])

# %%
encoding_dim = 20
# This is our input 
input_data = Input(shape=(42,)) # 42 is the number of features/columns
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_data)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(42, activation='relu')(encoded)
# This model maps an input to its reconstruction
autoencoder = Model(input_data, decoded)
# create a separate encoder model:
# This model maps an input to its encoded representation
encoder = Model(input_data, encoded)
# create a separate decoder model:
encoded_input = Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))
# Configure the model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
# train the model
autoencoder.fit(X_all_sc,
                X_all_sc,
                epochs=50)
# predict after training
encoded_input = encoder.predict(X_all_sc)
autoencoder_df = pd.DataFrame(data = encoded_input, columns=['autoencoder'+str(i) for i in range(encoded_input.shape[1])])
all_autoencoder = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], autoencoder_df], axis=1)
# Out:
# Epoch 1/50
# 286/286 [==============================] - 0s 674us/step - loss: 0.1332
# Epoch 2/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0506
# Epoch 3/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0288
# Epoch 4/50
# 286/286 [==============================] - 0s 722us/step - loss: 0.0213
# Epoch 5/50
# 286/286 [==============================] - 0s 728us/step - loss: 0.0175
# Epoch 6/50
# 286/286 [==============================] - 0s 708us/step - loss: 0.0151
# Epoch 7/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0135
# Epoch 8/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0124
# Epoch 9/50
# 286/286 [==============================] - 0s 708us/step - loss: 0.0116
# Epoch 10/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0111
# Epoch 11/50
# 286/286 [==============================] - 0s 692us/step - loss: 0.0107
# Epoch 12/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0103
# Epoch 13/50
# 286/286 [==============================] - 0s 697us/step - loss: 0.0099
# Epoch 14/50
# 286/286 [==============================] - 0s 701us/step - loss: 0.0095
# Epoch 15/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0092
# Epoch 16/50
# 286/286 [==============================] - 0s 718us/step - loss: 0.0090
# Epoch 17/50
# 286/286 [==============================] - 0s 697us/step - loss: 0.0088
# Epoch 18/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0086
# Epoch 19/50
# 286/286 [==============================] - 0s 684us/step - loss: 0.0085
# Epoch 20/50
# 286/286 [==============================] - 0s 701us/step - loss: 0.0084
# Epoch 21/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0083
# Epoch 22/50
# 286/286 [==============================] - 0s 712us/step - loss: 0.0083
# Epoch 23/50
# 286/286 [==============================] - 0s 713us/step - loss: 0.0082
# Epoch 24/50
# 286/286 [==============================] - 0s 698us/step - loss: 0.0082
# Epoch 25/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0082
# Epoch 26/50
# 286/286 [==============================] - 0s 708us/step - loss: 0.0082
# Epoch 27/50
# 286/286 [==============================] - 0s 724us/step - loss: 0.0081
# Epoch 28/50
# 286/286 [==============================] - 0s 715us/step - loss: 0.0081
# Epoch 29/50
# 286/286 [==============================] - 0s 717us/step - loss: 0.0081
# Epoch 30/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0081
# Epoch 31/50
# 286/286 [==============================] - 0s 705us/step - loss: 0.0081
# Epoch 32/50
# 286/286 [==============================] - 0s 706us/step - loss: 0.0081
# Epoch 33/50
# 286/286 [==============================] - 0s 721us/step - loss: 0.0081
# Epoch 34/50
# 286/286 [==============================] - 0s 709us/step - loss: 0.0080
# Epoch 35/50
# 286/286 [==============================] - 0s 729us/step - loss: 0.0080
# Epoch 36/50
# 286/286 [==============================] - 0s 704us/step - loss: 0.0080
# Epoch 37/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0080
# Epoch 38/50
# 286/286 [==============================] - 0s 728us/step - loss: 0.0080
# Epoch 39/50
# 286/286 [==============================] - 0s 771us/step - loss: 0.0080
# Epoch 40/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0080
# Epoch 41/50
# 286/286 [==============================] - 0s 697us/step - loss: 0.0080
# Epoch 42/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0080
# Epoch 43/50
# 286/286 [==============================] - 0s 705us/step - loss: 0.0080
# Epoch 44/50
# 286/286 [==============================] - 0s 726us/step - loss: 0.0080
# Epoch 45/50
# 286/286 [==============================] - 0s 715us/step - loss: 0.0080
# Epoch 46/50
# 286/286 [==============================] - 0s 720us/step - loss: 0.0080
# Epoch 47/50
# 286/286 [==============================] - 0s 709us/step - loss: 0.0080
# Epoch 48/50
# 286/286 [==============================] - 0s 703us/step - loss: 0.0080
# Epoch 49/50
# 286/286 [==============================] - 0s 703us/step - loss: 0.0080
# Epoch 50/50
# 286/286 [==============================] - 0s 719us/step - loss: 0.0080

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_autoencoder[all_autoencoder['Effective_Date'] <= '2011-09-30']
test = all_autoencoder[all_autoencoder['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': encoding_dim,
        'rmse_train_autoencoder': rmse_train,
        'rmse_test_autoencoder': rmse_test
    }
score.append(score_dict)
score_3M_aut_4 = pd.DataFrame(score, columns = ['features','rmse_train_autoencoder', 'rmse_test_autoencoder'])

# %%
encoding_dim = 25 
# This is our input 
input_data = Input(shape=(42,)) # 42 is the number of features/columns
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_data)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(42, activation='relu')(encoded)
# This model maps an input to its reconstruction
autoencoder = Model(input_data, decoded)
# create a separate encoder model:
# This model maps an input to its encoded representation
encoder = Model(input_data, encoded)
# create a separate decoder model:
encoded_input = Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))
# Configure the model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
# train the model
autoencoder.fit(X_all_sc,
                X_all_sc,
                epochs=50)
# predict after training
encoded_input = encoder.predict(X_all_sc)
autoencoder_df = pd.DataFrame(data = encoded_input, columns=['autoencoder'+str(i) for i in range(encoded_input.shape[1])])
all_autoencoder = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], autoencoder_df], axis=1)
# Out:
# Epoch 1/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.1259
# Epoch 2/50
# 286/286 [==============================] - 0s 689us/step - loss: 0.0379
# Epoch 3/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0193
# Epoch 4/50
# 286/286 [==============================] - 0s 712us/step - loss: 0.0139
# Epoch 5/50
# 286/286 [==============================] - 0s 711us/step - loss: 0.0109
# Epoch 6/50
# 286/286 [==============================] - 0s 722us/step - loss: 0.0089
# Epoch 7/50
# 286/286 [==============================] - 0s 718us/step - loss: 0.0083
# Epoch 8/50
# 286/286 [==============================] - 0s 716us/step - loss: 0.0079
# Epoch 9/50
# 286/286 [==============================] - 0s 697us/step - loss: 0.0077
# Epoch 10/50
# 286/286 [==============================] - 0s 692us/step - loss: 0.0075
# Epoch 11/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0074
# Epoch 12/50
# 286/286 [==============================] - 0s 706us/step - loss: 0.0073
# Epoch 13/50
# 286/286 [==============================] - 0s 710us/step - loss: 0.0072
# Epoch 14/50
# 286/286 [==============================] - 0s 705us/step - loss: 0.0072
# Epoch 15/50
# 286/286 [==============================] - 0s 707us/step - loss: 0.0072
# Epoch 16/50
# 286/286 [==============================] - 0s 694us/step - loss: 0.0072
# Epoch 17/50
# 286/286 [==============================] - 0s 712us/step - loss: 0.0071
# Epoch 18/50
# 286/286 [==============================] - 0s 703us/step - loss: 0.0071
# Epoch 19/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0071
# Epoch 20/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0071
# Epoch 21/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0071
# Epoch 22/50
# 286/286 [==============================] - 0s 693us/step - loss: 0.0071
# Epoch 23/50
# 286/286 [==============================] - 0s 720us/step - loss: 0.0071
# Epoch 24/50
# 286/286 [==============================] - 0s 704us/step - loss: 0.0071
# Epoch 25/50
# 286/286 [==============================] - 0s 704us/step - loss: 0.0071
# Epoch 26/50
# 286/286 [==============================] - 0s 698us/step - loss: 0.0071
# Epoch 27/50
# 286/286 [==============================] - 0s 715us/step - loss: 0.0071
# Epoch 28/50
# 286/286 [==============================] - 0s 714us/step - loss: 0.0071
# Epoch 29/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0071
# Epoch 30/50
# 286/286 [==============================] - 0s 729us/step - loss: 0.0071
# Epoch 31/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0071
# Epoch 32/50
# 286/286 [==============================] - 0s 698us/step - loss: 0.0071
# Epoch 33/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0071
# Epoch 34/50
# 286/286 [==============================] - 0s 722us/step - loss: 0.0071
# Epoch 35/50
# 286/286 [==============================] - 0s 700us/step - loss: 0.0071
# Epoch 36/50
# 286/286 [==============================] - 0s 696us/step - loss: 0.0071
# Epoch 37/50
# 286/286 [==============================] - 0s 695us/step - loss: 0.0071
# Epoch 38/50
# 286/286 [==============================] - 0s 706us/step - loss: 0.0071
# Epoch 39/50
# 286/286 [==============================] - 0s 691us/step - loss: 0.0071
# Epoch 40/50
# 286/286 [==============================] - 0s 703us/step - loss: 0.0071
# Epoch 41/50
# 286/286 [==============================] - 0s 692us/step - loss: 0.0071
# Epoch 42/50
# 286/286 [==============================] - 0s 692us/step - loss: 0.0071
# Epoch 43/50
# 286/286 [==============================] - 0s 702us/step - loss: 0.0071
# Epoch 44/50
# 286/286 [==============================] - 0s 702us/step - loss: 0.0071
# Epoch 45/50
# 286/286 [==============================] - 0s 709us/step - loss: 0.0071
# Epoch 46/50
# 286/286 [==============================] - 0s 699us/step - loss: 0.0071
# Epoch 47/50
# 286/286 [==============================] - 0s 692us/step - loss: 0.0071
# Epoch 48/50
# 286/286 [==============================] - 0s 689us/step - loss: 0.0071
# Epoch 49/50
# 286/286 [==============================] - 0s 702us/step - loss: 0.0071
# Epoch 50/50
# 286/286 [==============================] - 0s 714us/step - loss: 0.0071

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_autoencoder[all_autoencoder['Effective_Date'] <= '2011-09-30']
test = all_autoencoder[all_autoencoder['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': encoding_dim,
        'rmse_train_autoencoder': rmse_train,
        'rmse_test_autoencoder': rmse_test
    }
score.append(score_dict)
score_3M_aut_5 = pd.DataFrame(score, columns = ['features','rmse_train_autoencoder', 'rmse_test_autoencoder'])

# %%
score_aut = score_3M_aut_1.append(score_3M_aut_2)
score_aut = score_aut.append(score_3M_aut_3)
score_aut = score_aut.append(score_3M_aut_4)
score_aut = score_aut.append(score_3M_aut_5)
score_aut
# Out:
#    features  rmse_train_autoencoder  rmse_test_autoencoder
# 0         5                0.630223               0.661015
# 0        10                0.605617               0.640212
# 0        15                0.582467               0.620691
# 0        20                0.572760               0.613534
# 0        25                0.549484               0.608422

# %% [markdown]
# # Isomap Modeling & Prediction

# %%
components=5
np.random.seed(0)
isomap = Isomap(n_components=components)
isomap_embedd = isomap.fit_transform(X_all_sc)
isomap_embedd_df = pd.DataFrame(data = isomap_embedd, columns=['embedding'+str(i) for i in range(isomap_embedd.shape[1])])
all_isomap = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], isomap_embedd_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_isomap[all_isomap['Effective_Date'] <= '2011-09-30']
test = all_isomap[all_isomap['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_isomap': rmse_train,
        'rmse_test_isomap': rmse_test
    }
score.append(score_dict)
score_3M_iso_1 = pd.DataFrame(score, columns = ['features','rmse_train_isomap', 'rmse_test_isomap'])

# %%
components=10
np.random.seed(0)
isomap = Isomap(n_components=components)
isomap_embedd = isomap.fit_transform(X_all_sc)
isomap_embedd_df = pd.DataFrame(data = isomap_embedd, columns=['embedding'+str(i) for i in range(isomap_embedd.shape[1])])
all_isomap = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], isomap_embedd_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_isomap[all_isomap['Effective_Date'] <= '2011-09-30']
test = all_isomap[all_isomap['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_isomap': rmse_train,
        'rmse_test_isomap': rmse_test
    }
score.append(score_dict)
score_3M_iso_2 = pd.DataFrame(score, columns = ['features','rmse_train_isomap', 'rmse_test_isomap'])

# %%
components=15
np.random.seed(0)
isomap = Isomap(n_components=components)
isomap_embedd = isomap.fit_transform(X_all_sc)
isomap_embedd_df = pd.DataFrame(data = isomap_embedd, columns=['embedding'+str(i) for i in range(isomap_embedd.shape[1])])
all_isomap = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], isomap_embedd_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_isomap[all_isomap['Effective_Date'] <= '2011-09-30']
test = all_isomap[all_isomap['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_isomap': rmse_train,
        'rmse_test_isomap': rmse_test
    }
score.append(score_dict)
score_3M_iso_3 = pd.DataFrame(score, columns = ['features','rmse_train_isomap', 'rmse_test_isomap'])

# %%
components=20
np.random.seed(0)
isomap = Isomap(n_components=components)
isomap_embedd = isomap.fit_transform(X_all_sc)
isomap_embedd_df = pd.DataFrame(data = isomap_embedd, columns=['embedding'+str(i) for i in range(isomap_embedd.shape[1])])
all_isomap = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], isomap_embedd_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_isomap[all_isomap['Effective_Date'] <= '2011-09-30']
test = all_isomap[all_isomap['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_isomap': rmse_train,
        'rmse_test_isomap': rmse_test
    }
score.append(score_dict)
score_3M_iso_4 = pd.DataFrame(score, columns = ['features','rmse_train_isomap', 'rmse_test_isomap'])

# %%
components=25
np.random.seed(0)
isomap = Isomap(n_components=components)
isomap_embedd = isomap.fit_transform(X_all_sc)
isomap_embedd_df = pd.DataFrame(data = isomap_embedd, columns=['embedding'+str(i) for i in range(isomap_embedd.shape[1])])
all_isomap = pd.concat([df_new[['Customer_Lifetime_Value','Effective_Date']], isomap_embedd_df], axis=1)

# %%
# Split data set train/test set:test set is built on the last 3 months to the end of the year 
train = all_isomap[all_isomap['Effective_Date'] <= '2011-09-30']
test = all_isomap[all_isomap['Effective_Date'] >= '2011-10-01']
train = train.drop(['Effective_Date'], axis=1)
test = test.drop(['Effective_Date'], axis=1)

# %%
# fit the model
X_train = train.copy()
y_train = np.log1p(X_train.Customer_Lifetime_Value)
X_train.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_train_sc = scaling.fit_transform(X_train)
X_test = test.copy()
y_test = np.log1p(X_test.Customer_Lifetime_Value)
X_test.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)
# Normalization of data
X_test_sc = scaling.transform(X_test)
model = GradientBoostingRegressor(random_state=0)
kf = KFold(n_splits=5)
param_grid = {}
score = []
my_model = GridSearchCV(model,param_grid,cv=kf)
my_model.fit(X_train_sc, y_train)
predictions_tr = my_model.predict(X_train_sc) 
predictions_te = my_model.predict(X_test_sc)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_tr))
rmse_test = np.sqrt(mean_squared_error(y_test, predictions_te))
score_dict = {
        'features': components,
        'rmse_train_isomap': rmse_train,
        'rmse_test_isomap': rmse_test
    }
score.append(score_dict)
score_3M_iso_5 = pd.DataFrame(score, columns = ['features','rmse_train_isomap', 'rmse_test_isomap'])

# %%
score_iso = score_3M_iso_1.append(score_3M_iso_2)
score_iso = score_iso.append(score_3M_iso_3)
score_iso = score_iso.append(score_3M_iso_4)
score_iso = score_iso.append(score_3M_iso_5)
score_iso
# Out:
#    features  rmse_train_isomap  rmse_test_isomap
# 0         5           0.624898          0.665873
# 0        10           0.614544          0.660536
# 0        15           0.596003          0.650337
# 0        20           0.591350          0.648385
# 0        25           0.589879          0.649115

# %%
score = pd.concat([score_pca,score_aut['rmse_train_autoencoder'],score_aut['rmse_test_autoencoder'],score_iso['rmse_train_isomap'],score_iso['rmse_test_isomap']], axis=1)
score
# Out:
#    features  rmse_train_pca  rmse_test_pca  rmse_train_autoencoder  \
# 0         5        0.625759       0.663359                0.630223
# 0        10        0.615976       0.659641                0.605617
# 0        15        0.585712       0.628892                0.582467
# 0        20        0.575250       0.626842                0.572760
# 0        25        0.490460       0.561257                0.549484
#
#    rmse_test_autoencoder  rmse_train_isomap  rmse_test_isomap
# 0               0.661015           0.624898          0.665873
# 0               0.640212           0.614544          0.660536
# 0               0.620691           0.596003          0.650337
# 0               0.613534           0.591350          0.648385
# 0               0.608422           0.589879          0.649115

# %%
sns.set(rc = {'figure.figsize': (10, 5)})
score.plot(x='features', y=['rmse_train_pca','rmse_train_autoencoder','rmse_train_isomap'],
                           color=['blue','red','green'])
plt.ylabel('rmse_train')
plt.xlabel('Number_of_Features')
plt.title('rmse train vs dimensionality reduction')
plt.show()
score.plot(x='features', y=['rmse_test_pca','rmse_test_autoencoder','rmse_test_isomap'],
                           color=['blue','red','green'])
plt.ylabel('rmse_test')
plt.xlabel('Number_of_Features')
plt.title('rmse test vs dimensionality reduction')
plt.show()
