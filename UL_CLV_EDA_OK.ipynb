# %% [markdown]
# # Unsupervised Learning applied to Customer Lifetime Value (CLV)

# %% [markdown]
# ![](https://wilsonprintingusa.com/wp-content/uploads/2015/02/Customer-Lifetime-Value-Wilson-Printing.jpg)

# %% [markdown]
# # Prepare Workspace

# %%
# Upload libraries
from numpy.random import seed
seed(1)
import tensorflow.keras
tensorflow.random.set_seed(2)

# to handle datasets
import numpy as np
import pandas as pd
import datetime

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot

# for statistics
import statistics as st 
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf


# to split data set 
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# to build models
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

# dimensionality reductiion
from sklearn.decomposition import PCA
from sklearn.manifold import Isomap
from sklearn.manifold import TSNE
from keras.layers import Input,Dense
from keras.models import Model

# clustering
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors

# to evaluate models
from sklearn.metrics import median_absolute_error
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('AutoInsurance.csv')

# %% [markdown]
# # Data set Overview

# %%
# Dimensions of data set
print(df.shape)
# Out:
# (9134, 24)

# %%
# List types for each attribute
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB
# None

# %%
# Take a peek at the first rows of the data
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4          3/2/2011         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %% [markdown]
# # Data Cleaning & Handling Variables Activity

# %%
# Change format Date
df_1 = df.copy()
df_1['Effective_Date'] = pd.to_datetime(df_1['Effective To Date'])

# %% [markdown]
# ### Handling Missing Values

# %%
# Check missing values both to numeric features and categorical features 
missing = df_1.isnull().sum()/df_1.shape[0]*100
missing
# Out:
# Customer                         0.0
# State                            0.0
# Customer Lifetime Value          0.0
# Response                         0.0
# Coverage                         0.0
# Education                        0.0
# Effective To Date                0.0
# EmploymentStatus                 0.0
# Gender                           0.0
# Income                           0.0
# Location Code                    0.0
# Marital Status                   0.0
# Monthly Premium Auto             0.0
# Months Since Last Claim          0.0
# Months Since Policy Inception    0.0
# Number of Open Complaints        0.0
# Number of Policies               0.0
# Policy Type                      0.0
# Policy                           0.0
# Renew Offer Type                 0.0
# Sales Channel                    0.0
# Total Claim Amount               0.0
# Vehicle Class                    0.0
# Vehicle Size                     0.0
# Effective_Date                   0.0
# dtype: float64

# %%
# Min Value Effective to Date Policy
df_1['Effective_Date'].min()
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
# Max Value Effective to Date Policy
df_1['Effective_Date'].max()
# Out:
# Timestamp('2011-12-02 00:00:00')

# %%
# End of Year (eoy) of the current Effective to Date
df_1['eoy_Effective_Date'] = pd.to_datetime('2011-12-31')

# %%
# Days missing to the end of the current year from effective to date
df_1['eoy_missing_days'] = (df_1['eoy_Effective_Date'] - df_1['Effective_Date']).dt.days

# %%
# check duplicates
df_1_duplicates = df_1[df_1.duplicated(['Customer'])]

# %%
df_1_duplicates
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size, Effective_Date, eoy_Effective_Date, eoy_missing_days]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_1 = df_1.drop(['Customer','Effective To Date','eoy_Effective_Date'], axis=1)

# %%
# Rename some features for a practical use
df_new = df_1.copy()
df_new = df_new.rename(columns={"Customer Lifetime Value":"Customer_Lifetime_Value","Location Code":"Location_Code","Marital Status":"Marital_Status","Monthly Premium Auto":"Monthly_Premium_Auto","Months Since Last Claim":"Months_Since_Last_Claim",
                           "Months Since Policy Inception":"Months_Since_Policy_Inception","Number of Open Complaints":"Number_of_Open_Complaints","Number of Policies":"Number_of_Policies",
                           "Policy Type":"Policy_Type","Renew Offer Type":"Renew_Offer_Type","Sales Channel":"Sales_Channel","Total Claim Amount":"Total_Claim_Amount",
                           "Vehicle Class":"Vehicle_Class","Vehicle Size":"Vehicle_Size"})

# %% [markdown]
# # Summary Statistics

# %%
# Summarize attribute distributions for data type of variables
obj_cols = [var for var in df_new.columns if df_new[var].dtype=='object']
df_new[obj_cols].describe().T
# Out:
#                  count unique            top  freq
# State             9134      5     California  3150
# Response          9134      2             No  7826
# Coverage          9134      3          Basic  5568
# Education         9134      5       Bachelor  2748
# EmploymentStatus  9134      5       Employed  5698
# Gender            9134      2              F  4658
# Location_Code     9134      3       Suburban  5779
# Marital_Status    9134      3        Married  5298
# Policy_Type       9134      3  Personal Auto  6788
# Policy            9134      9    Personal L3  3426
# Renew_Offer_Type  9134      4         Offer1  3752
# Sales_Channel     9134      4          Agent  3477
# Vehicle_Class     9134      6  Four-Door Car  4621
# Vehicle_Size      9134      3        Medsize  6424

# %%
# Summarize attribute distributions for data type of variables
no_obj_cols = [var for var in df_new.columns if df_new[var].dtype!='object']
df_new[no_obj_cols].describe().T
# Out:
#                                 count          mean           std  \
# Customer_Lifetime_Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly_Premium_Auto           9134.0     93.219291     34.407967
# Months_Since_Last_Claim        9134.0     15.097000     10.073257
# Months_Since_Policy_Inception  9134.0     48.064594     27.905991
# Number_of_Open_Complaints      9134.0      0.384388      0.910384
# Number_of_Policies             9134.0      2.966170      2.390182
# Total_Claim_Amount             9134.0    434.088794    290.500092
# eoy_missing_days               9134.0    276.667068     93.820412
#
#                                        min          25%           50%  \
# Customer_Lifetime_Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly_Premium_Auto             61.000000    68.000000     83.000000
# Months_Since_Last_Claim           0.000000     6.000000     14.000000
# Months_Since_Policy_Inception     0.000000    24.000000     48.000000
# Number_of_Open_Complaints         0.000000     0.000000      0.000000
# Number_of_Policies                1.000000     1.000000      2.000000
# Total_Claim_Amount                0.099007   272.258244    383.945434
# eoy_missing_days                 29.000000   244.000000    315.000000
#
#                                         75%           max
# Customer_Lifetime_Value         8962.167041  83325.381190
# Income                         62320.000000  99981.000000
# Monthly_Premium_Auto             109.000000    298.000000
# Months_Since_Last_Claim           23.000000     35.000000
# Months_Since_Policy_Inception     71.000000     99.000000
# Number_of_Open_Complaints          0.000000      5.000000
# Number_of_Policies                 4.000000      9.000000
# Total_Claim_Amount               547.514839   2893.239678
# eoy_missing_days                 340.000000    364.000000

# %%
# Split data set between target variable and features
X_full = df_new.copy()
y = X_full.Customer_Lifetime_Value
X_full.drop(['Customer_Lifetime_Value'], axis=1, inplace=True)

# %% [markdown]
# # Target Variable Analysis

# %%
# Univariate analysis looking at Mean, Variance, Standard Deviation, Skewness and Kurtosis
print(y.name,
      '\nMean :', np.mean(y),
      '\nVariance :', np.var(y),
      '\nStandard Deviation :', st.stdev(y), 
      '\nSkewness :', stats.skew(y), 
      '\nKurtosis :', stats.kurtosis(y))
# Out:
# Customer_Lifetime_Value
# Mean : 8004.940474987081
# Variance : 47205027.252813585
# Standard Deviation : 6870.9676083569375
# Skewness : 3.0317822713278852
# Kurtosis : 13.815310695287444

# %%
# Univariate analysis with density plots and histogram
sns.set( rc = {'figure.figsize': (25, 8)})
plt.subplot(1,4,1)  
sns.histplot(y, bins=10)
plt.xticks(rotation=45)
plt.title('CLV histogram')
# Univariate analysis with box-plots
plt.subplot(1,4,2)
sns.boxplot(y,palette="Set1",linewidth=1)
plt.xticks(rotation=45)
plt.title('CLV box-plot')
# Univariate analysis with QQ-plot
plt.subplot(1,4,3)  
res = stats.probplot(y, plot=plt)
plt.title('CLV Q-Q plot')
# Univariate analysis with density plot
plt.subplot(1,4,4)
sns.kdeplot(y,palette="Set1",linewidth=1)
plt.xticks(rotation=45)
plt.title('CLV density plot') 
df_t = df_new.groupby(['Effective_Date'], as_index=False)['Customer_Lifetime_Value'].sum()
df_clv = pd.DataFrame(df_t).set_index('Effective_Date')
fig = plt.figure(figsize = (5,5))
# autocorrelation plot CLV
autocorrelation_plot(df_clv)
plt.title("CLV vs Effective_Date autocorrelation") 
plt.show()

# %% [markdown]
# # Numerical Features Analysis

# %% [markdown]
# ### Analysis for numerical features (univariate analysis, bivariate analysis)

# %%
# Select numerical columns
numerical_cols = [cname for cname in X_full.columns if 
                X_full[cname].dtype in ['float64','int64']]

# %%
# Subset with numerical features
num = X_full[numerical_cols]
num.columns
# Out:
# Index(['Income', 'Monthly_Premium_Auto', 'Months_Since_Last_Claim',
#        'Months_Since_Policy_Inception', 'Number_of_Open_Complaints',
#        'Number_of_Policies', 'Total_Claim_Amount', 'eoy_missing_days'],
#       dtype='object')

# %%
# list of numerical features
fnum = ['Income', 'Monthly_Premium_Auto', 'Months_Since_Last_Claim',
       'Months_Since_Policy_Inception', 'Number_of_Open_Complaints',
       'Number_of_Policies', 'Total_Claim_Amount', 'eoy_missing_days']

# %%
# Univariate analysis looking at Mean, Standard Deviation, Skewness and Kurtosis
for col in fnum:
    print(col,
        '\nMean :', np.mean(num[col]),  
        '\nVariance :', np.var(num[col]),
        '\nStandard Deviation :', st.stdev(num[col]), 
        '\nSkewness :', stats.skew(num[col]), 
        '\nKurtosis :', stats.kurtosis(num[col]))
# Out:
# Income
# Mean : 37657.38000875848
# Variance : 922837567.3402659
# Standard Deviation : 30379.9047338463
# Skewness : 0.28684016057807576
# Kurtosis : -1.094383828097193
# Monthly_Premium_Auto
# Mean : 93.21929056273265
# Variance : 1183.77860313147
# Standard Deviation : 34.40796737178653
# Skewness : 2.123197701864424
# Kurtosis : 6.189558258832852
# Months_Since_Last_Claim
# Mean : 15.097000218962119
# Variance : 101.45938885548495
# Standard Deviation : 10.073256571394225
# Skewness : 0.2785405598366762
# Kurtosis : -1.0737368448075961
# Months_Since_Policy_Inception
# Mean : 48.064593825268226
# Variance : 778.6590638978643
# Standard Deviation : 27.90599078426519
# Skewness : 0.040158365343045704
# Kurtosis : -1.1330825805856537
# Number_of_Open_Complaints
# Mean : 0.38438800087584846
# Variance : 0.828707436930687
# Standard Deviation : 0.910383531613565
# Skewness : 2.7828059596647505
# Kurtosis : 7.744410297233042
# Number_of_Policies
# Mean : 2.9661703525290126
# Variance : 5.712343621516475
# Standard Deviation : 2.390181809701136
# Skewness : 1.2531269015899718
# Kurtosis : 0.36230101435395934
# Total_Claim_Amount
# Mean : 434.0887943128969
# Variance : 84381.06419777304
# Standard Deviation : 290.50009180311343
# Skewness : 1.7146841624611302
# Kurtosis : 5.975471577225969
# eoy_missing_days
# Mean : 276.66706809721916
# Variance : 8801.30595074268
# Standard Deviation : 93.82041159870538
# Skewness : -1.3911693543532206
# Kurtosis : 0.5880448511919951

# %%
# Univariate analysis with density plots and histograms

for col in fnum:
    plt.figure(figsize=(5,5))
    sns.displot(x=num[col], bins=10, color='green', kde=True)
    plt.xticks(rotation=45)
    plt.show()

# %%
# Univariate analysis with box-plots
for col in fnum:
    plt.figure(figsize=(5,5))
    sns.boxplot(x=num[col], color="green")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Univariate analysis with Q-Q plot
for col in fnum:
    plt.figure(figsize=(5,5))
    res = stats.probplot(num[col], plot=plt)
    plt.title('{} Q-Q plot'.format(col))
    plt.xticks(rotation=45)
    plt.show()

# %%
# new subset for a bivariate analysis
num2 = pd.concat([y,num], axis=1)

# %%
# Bivariate analysis with scatter-plot matrix
sns.pairplot(num2, kind ='scatter',diag_kind='kde')
plt.show()

# %% [markdown]
# ### Dimensionality Reduction and Visualization with T-SNE

# %%
# Normalization of data
scaling = MinMaxScaler()
num_sc = scaling.fit_transform(num)

# %%
tsne = TSNE(n_components=2, random_state=0).fit_transform(num_sc)

# %%
tsne_df = pd.DataFrame(data = tsne, columns = ['x','y'], index=num.index)

# %%
dff = pd.concat([df_new['Customer_Lifetime_Value'], tsne_df], axis=1)
# Show the diagram
fig = plt.subplots(figsize=(10, 10))
sns.scatterplot(x='x',y='y',hue='Customer_Lifetime_Value',data=dff)
plt.title('t-SNE visualization of numerical variables')
plt.show()

# %% [markdown]
# # Categorical Features Analysis

# %% [markdown]
# ### Analysis for categorical features (univariate analysis, bivariate analysis)

# %%
# let's have a look at how many labels for categorical features
for col in X_full.columns:
    if X_full[col].dtype =="object":
        print(col, ': ', len(X_full[col].unique()), ' labels')
# Out:
# State :  5  labels
# Response :  2  labels
# Coverage :  3  labels
# Education :  5  labels
# EmploymentStatus :  5  labels
# Gender :  2  labels
# Location_Code :  3  labels
# Marital_Status :  3  labels
# Policy_Type :  3  labels
# Policy :  9  labels
# Renew_Offer_Type :  4  labels
# Sales_Channel :  4  labels
# Vehicle_Class :  6  labels
# Vehicle_Size :  3  labels

# %%
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X_full.columns if
                    X_full[cname].nunique() <= 15 and 
                    X_full[cname].dtype == "object"]

# %%
# Subset with categorical features
cat = X_full[categorical_cols]
cat.columns
# Out:
# Index(['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus',
#        'Gender', 'Location_Code', 'Marital_Status', 'Policy_Type', 'Policy',
#        'Renew_Offer_Type', 'Sales_Channel', 'Vehicle_Class', 'Vehicle_Size'],
#       dtype='object')

# %%
# List of categorical features
fcat = ['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus',
       'Gender', 'Location_Code', 'Marital_Status', 'Policy_Type', 'Policy',
       'Renew_Offer_Type', 'Sales_Channel', 'Vehicle_Class', 'Vehicle_Size']

# %%
# Univariate analysis looking at frequency
for col in fcat:
    count = pd.crosstab(index = cat[col], columns="count")
    percentage = pd.crosstab(index = cat[col], columns="frequency")/pd.crosstab(index = cat[col], columns="frequency").sum()
    tab = pd.concat([count, percentage], axis=1)
    print('\n',tab)
# Out:
#  col_0       count  frequency
# State
# Arizona      1703   0.186446
# California   3150   0.344865
# Nevada        882   0.096562
# Oregon       2601   0.284760
# Washington    798   0.087366
#
#  col_0     count  frequency
# Response
# No         7826   0.856799
# Yes        1308   0.143201
#
#  col_0     count  frequency
# Coverage
# Basic      5568   0.609591
# Extended   2742   0.300197
# Premium     824   0.090212
#
#  col_0                 count  frequency
# Education
# Bachelor               2748   0.300854
# College                2681   0.293519
# Doctor                  342   0.037443
# High School or Below   2622   0.287059
# Master                  741   0.081125
#
#  col_0             count  frequency
# EmploymentStatus
# Disabled            405   0.044340
# Employed           5698   0.623823
# Medical Leave       432   0.047296
# Retired             282   0.030874
# Unemployed         2317   0.253668
#
#  col_0   count  frequency
# Gender
# F        4658   0.509963
# M        4476   0.490037
#
#  col_0          count  frequency
# Location_Code
# Rural           1773   0.194110
# Suburban        5779   0.632691
# Urban           1582   0.173199
#
#  col_0           count  frequency
# Marital_Status
# Divorced         1369   0.149880
# Married          5298   0.580031
# Single           2467   0.270090
#
#  col_0           count  frequency
# Policy_Type
# Corporate Auto   1968   0.215459
# Personal Auto    6788   0.743157
# Special Auto      378   0.041384
#
#  col_0         count  frequency
# Policy
# Corporate L1    359   0.039304
# Corporate L2    595   0.065141
# Corporate L3   1014   0.111014
# Personal L1    1240   0.135757
# Personal L2    2122   0.232319
# Personal L3    3426   0.375082
# Special L1       66   0.007226
# Special L2      164   0.017955
# Special L3      148   0.016203
#
#  col_0             count  frequency
# Renew_Offer_Type
# Offer1             3752   0.410773
# Offer2             2926   0.320342
# Offer3             1432   0.156777
# Offer4             1024   0.112109
#
#  col_0          count  frequency
# Sales_Channel
# Agent           3477   0.380666
# Branch          2567   0.281038
# Call Center     1765   0.193234
# Web             1325   0.145062
#
#  col_0          count  frequency
# Vehicle_Class
# Four-Door Car   4621   0.505912
# Luxury Car       163   0.017845
# Luxury SUV       184   0.020145
# SUV             1796   0.196628
# Sports Car       484   0.052989
# Two-Door Car    1886   0.206481
#
#  col_0         count  frequency
# Vehicle_Size
# Large           946   0.103569
# Medsize        6424   0.703306
# Small          1764   0.193125

# %%
# Univariate analysis with barplots

for col in fcat:
    plt.figure(figsize=(5,5))
    sns.countplot(x=cat[col], data=cat, palette="Set1")
    plt.xticks(rotation=90)
    plt.show()

# %%
# new subset for a bivariate analysis
cat2 = pd.concat([y,cat], axis=1)

# %%
# Bivariate analysis with box-plots
for col in fcat:
    plt.figure(figsize=(5,5))
    sns.boxplot(y=cat2[col], x=cat2['Customer_Lifetime_Value'], linewidth=2, palette="Set2")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Bivariate analysis with barplots
for col in fcat:
    plt.figure(figsize=(10,5))
    sns.barplot(y=cat2['Customer_Lifetime_Value'], x=cat2[col], palette="Set2")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Function for query and barplot about Customer_Lifetime_Value per each class of variable
def query(data,col):
    # groupby
    df = data.groupby(data[col], as_index=False)['Customer_Lifetime_Value'].sum()
    df['PERCENTAGE'] = df['Customer_Lifetime_Value']/df['Customer_Lifetime_Value'].sum()*100
    # dropping not matching rows
    df = df.dropna()
    # ranking 
    df = df.sort_values(by = 'Customer_Lifetime_Value', ascending = False).reset_index(drop=True)
    df_q = df.style.background_gradient(cmap='winter').format({'PERCENTAGE': "{:.2f}"}).format({'Customer_Lifetime_Value':"{:,.2f}"})
    # barplot
    index=list(df.columns[0:1])
    barplot = df[df.columns[0:2]].sort_values(by = "Customer_Lifetime_Value", ascending = True).set_index(index).plot.barh()
    plt.xticks(rotation=0)
    plt.legend(loc='best', bbox_to_anchor=(1, 0.5))
    return df_q
    plt.show()
    return barplot
    plt.show()

# %%
# query and barplot
variable = 'State'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='State')
# Out:
# Customer_Lifetime_Value per State
# <style  type="text/css" >
# #T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row0_col1,#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row1_col1,#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row1_col2{
#             background-color:  #00c69c;
#             color:  #000000;
#         }#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row2_col1,#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row2_col2{
#             background-color:  #005fd0;
#             color:  #f1f1f1;
#         }#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row3_col1,#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row3_col2{
#             background-color:  #0009fa;
#             color:  #f1f1f1;
#         }#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row4_col1,#T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row4_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >State</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row0_col0" class="data row0 col0" >California</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row0_col1" class="data row0 col1" >25,211,490.44</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row0_col2" class="data row0 col2" >34.48</td>
#             </tr>
#             <tr>
#                         <th id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row1_col0" class="data row1 col0" >Oregon</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row1_col1" class="data row1 col1" >21,010,621.00</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row1_col2" class="data row1 col2" >28.74</td>
#             </tr>
#             <tr>
#                         <th id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row2_col0" class="data row2 col0" >Arizona</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row2_col1" class="data row2 col1" >13,387,864.56</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row2_col2" class="data row2 col2" >18.31</td>
#             </tr>
#             <tr>
#                         <th id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row3_col0" class="data row3 col0" >Nevada</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row3_col1" class="data row3 col1" >7,106,015.43</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row3_col2" class="data row3 col2" >9.72</td>
#             </tr>
#             <tr>
#                         <th id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row4_col0" class="data row4 col0" >Washington</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row4_col1" class="data row4 col1" >6,401,134.87</td>
#                         <td id="T_f0b0a956_a3a6_11eb_bed3_acfdcef35164row4_col2" class="data row4 col2" >8.75</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Response'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Response')
# Out:
# Customer_Lifetime_Value per Response
# <style  type="text/css" >
# #T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row0_col1,#T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row1_col1,#T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row1_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Response</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row0_col0" class="data row0 col0" >No</td>
#                         <td id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row0_col1" class="data row0 col1" >62,842,954.56</td>
#                         <td id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row0_col2" class="data row0 col2" >85.95</td>
#             </tr>
#             <tr>
#                         <th id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row1_col0" class="data row1 col0" >Yes</td>
#                         <td id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row1_col1" class="data row1 col1" >10,274,171.74</td>
#                         <td id="T_f0d5a8de_a3a6_11eb_8c2e_acfdcef35164row1_col2" class="data row1 col2" >14.05</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Coverage'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Coverage')
# Out:
# Customer_Lifetime_Value per Coverage
# <style  type="text/css" >
# #T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row0_col1,#T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row1_col1,#T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row1_col2{
#             background-color:  #007cc1;
#             color:  #f1f1f1;
#         }#T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row2_col1,#T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row2_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coverage</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row0_col0" class="data row0 col0" >Basic</td>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row0_col1" class="data row0 col1" >40,037,853.36</td>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row0_col2" class="data row0 col2" >54.76</td>
#             </tr>
#             <tr>
#                         <th id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row1_col0" class="data row1 col0" >Extended</td>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row1_col1" class="data row1 col1" >24,101,296.00</td>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row1_col2" class="data row1 col2" >32.96</td>
#             </tr>
#             <tr>
#                         <th id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row2_col0" class="data row2 col0" >Premium</td>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row2_col1" class="data row2 col1" >8,977,976.94</td>
#                         <td id="T_f0f783fa_a3a6_11eb_abb6_acfdcef35164row2_col2" class="data row2 col2" >12.28</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Education'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Education')
# Out:
# Customer_Lifetime_Value per Education
# <style  type="text/css" >
# #T_f11b3324_a3a6_11eb_bf34_acfdcef35164row0_col1,#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row1_col1,#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row1_col2{
#             background-color:  #00fe80;
#             color:  #000000;
#         }#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row2_col1,#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row2_col2{
#             background-color:  #00f684;
#             color:  #000000;
#         }#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row3_col1,#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row3_col2{
#             background-color:  #002fe8;
#             color:  #f1f1f1;
#         }#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row4_col1,#T_f11b3324_a3a6_11eb_bf34_acfdcef35164row4_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Education</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row0_col0" class="data row0 col0" >High School or Below</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row0_col1" class="data row0 col1" >21,753,971.08</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row0_col2" class="data row0 col2" >29.75</td>
#             </tr>
#             <tr>
#                         <th id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row1_col0" class="data row1 col0" >Bachelor</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row1_col1" class="data row1 col1" >21,634,070.81</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row1_col2" class="data row1 col2" >29.59</td>
#             </tr>
#             <tr>
#                         <th id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row2_col0" class="data row2 col0" >College</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row2_col1" class="data row2 col1" >21,048,704.31</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row2_col2" class="data row2 col2" >28.79</td>
#             </tr>
#             <tr>
#                         <th id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row3_col0" class="data row3 col0" >Master</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row3_col1" class="data row3 col1" >6,108,422.16</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row3_col2" class="data row3 col2" >8.35</td>
#             </tr>
#             <tr>
#                         <th id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row4_col0" class="data row4 col0" >Doctor</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row4_col1" class="data row4 col1" >2,571,957.93</td>
#                         <td id="T_f11b3324_a3a6_11eb_bf34_acfdcef35164row4_col2" class="data row4 col2" >3.52</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'EmploymentStatus'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='EmploymentStatus')
# Out:
# Customer_Lifetime_Value per EmploymentStatus
# <style  type="text/css" >
# #T_f13f7344_a3a6_11eb_88ae_acfdcef35164row0_col1,#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row1_col1,#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row1_col2{
#             background-color:  #0059d2;
#             color:  #f1f1f1;
#         }#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row2_col1,#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row2_col2,#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row3_col1,#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row3_col2{
#             background-color:  #0006fc;
#             color:  #f1f1f1;
#         }#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row4_col1,#T_f13f7344_a3a6_11eb_88ae_acfdcef35164row4_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EmploymentStatus</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row0_col0" class="data row0 col0" >Employed</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row0_col1" class="data row0 col1" >46,832,532.96</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row0_col2" class="data row0 col2" >64.05</td>
#             </tr>
#             <tr>
#                         <th id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row1_col0" class="data row1 col0" >Unemployed</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row1_col1" class="data row1 col1" >17,693,352.89</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row1_col2" class="data row1 col2" >24.20</td>
#             </tr>
#             <tr>
#                         <th id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row2_col0" class="data row2 col0" >Medical Leave</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row2_col1" class="data row2 col1" >3,301,267.29</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row2_col2" class="data row2 col2" >4.52</td>
#             </tr>
#             <tr>
#                         <th id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row3_col0" class="data row3 col0" >Disabled</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row3_col1" class="data row3 col1" >3,178,395.19</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row3_col2" class="data row3 col2" >4.35</td>
#             </tr>
#             <tr>
#                         <th id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row4_col0" class="data row4 col0" >Retired</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row4_col1" class="data row4 col1" >2,111,577.97</td>
#                         <td id="T_f13f7344_a3a6_11eb_88ae_acfdcef35164row4_col2" class="data row4 col2" >2.89</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Gender'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Gender')
# Out:
# Customer_Lifetime_Value per Gender
# <style  type="text/css" >
# #T_f161ed8e_a3a6_11eb_9613_acfdcef35164row0_col1,#T_f161ed8e_a3a6_11eb_9613_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f161ed8e_a3a6_11eb_9613_acfdcef35164row1_col1,#T_f161ed8e_a3a6_11eb_9613_acfdcef35164row1_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Gender</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164row0_col0" class="data row0 col0" >F</td>
#                         <td id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164row0_col1" class="data row0 col1" >37,713,973.84</td>
#                         <td id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164row0_col2" class="data row0 col2" >51.58</td>
#             </tr>
#             <tr>
#                         <th id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164row1_col0" class="data row1 col0" >M</td>
#                         <td id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164row1_col1" class="data row1 col1" >35,403,152.46</td>
#                         <td id="T_f161ed8e_a3a6_11eb_9613_acfdcef35164row1_col2" class="data row1 col2" >48.42</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Location_Code'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Location_Code')
# Out:
# Customer_Lifetime_Value per Location_Code
# <style  type="text/css" >
# #T_f1834686_a3a6_11eb_9a68_acfdcef35164row0_col1,#T_f1834686_a3a6_11eb_9a68_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f1834686_a3a6_11eb_9a68_acfdcef35164row1_col1,#T_f1834686_a3a6_11eb_9a68_acfdcef35164row1_col2{
#             background-color:  #000afa;
#             color:  #f1f1f1;
#         }#T_f1834686_a3a6_11eb_9a68_acfdcef35164row2_col1,#T_f1834686_a3a6_11eb_9a68_acfdcef35164row2_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f1834686_a3a6_11eb_9a68_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Location_Code</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1834686_a3a6_11eb_9a68_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row0_col0" class="data row0 col0" >Suburban</td>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row0_col1" class="data row0 col1" >46,257,759.40</td>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row0_col2" class="data row0 col2" >63.27</td>
#             </tr>
#             <tr>
#                         <th id="T_f1834686_a3a6_11eb_9a68_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row1_col0" class="data row1 col0" >Rural</td>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row1_col1" class="data row1 col1" >14,101,908.60</td>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row1_col2" class="data row1 col2" >19.29</td>
#             </tr>
#             <tr>
#                         <th id="T_f1834686_a3a6_11eb_9a68_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row2_col0" class="data row2 col0" >Urban</td>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row2_col1" class="data row2 col1" >12,757,458.29</td>
#                         <td id="T_f1834686_a3a6_11eb_9a68_acfdcef35164row2_col2" class="data row2 col2" >17.45</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Marital_Status'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Marital_Status')
# Out:
# Customer_Lifetime_Value per Marital_Status
# <style  type="text/css" >
# #T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row0_col1,#T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row1_col1,#T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row1_col2{
#             background-color:  #003ee0;
#             color:  #f1f1f1;
#         }#T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row2_col1,#T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row2_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Marital_Status</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row0_col0" class="data row0 col0" >Married</td>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row0_col1" class="data row0 col1" >42,802,367.00</td>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row0_col2" class="data row0 col2" >58.54</td>
#             </tr>
#             <tr>
#                         <th id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row1_col0" class="data row1 col0" >Single</td>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row1_col1" class="data row1 col1" >19,032,502.92</td>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row1_col2" class="data row1 col2" >26.03</td>
#             </tr>
#             <tr>
#                         <th id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row2_col0" class="data row2 col0" >Divorced</td>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row2_col1" class="data row2 col1" >11,282,256.38</td>
#                         <td id="T_f1bd89c8_a3a6_11eb_b70b_acfdcef35164row2_col2" class="data row2 col2" >15.43</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Policy_Type'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Policy_Type')
# Out:
# Customer_Lifetime_Value per Policy_Type
# <style  type="text/css" >
# #T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row0_col1,#T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row1_col1,#T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row1_col2{
#             background-color:  #003ce1;
#             color:  #f1f1f1;
#         }#T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row2_col1,#T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row2_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Policy_Type</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row0_col0" class="data row0 col0" >Personal Auto</td>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row0_col1" class="data row0 col1" >54,489,743.68</td>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row0_col2" class="data row0 col2" >74.52</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row1_col0" class="data row1 col0" >Corporate Auto</td>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row1_col1" class="data row1 col1" >15,378,758.00</td>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row1_col2" class="data row1 col2" >21.03</td>
#             </tr>
#             <tr>
#                         <th id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row2_col0" class="data row2 col0" >Special Auto</td>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row2_col1" class="data row2 col1" >3,248,624.62</td>
#                         <td id="T_f1e1ba98_a3a6_11eb_8170_acfdcef35164row2_col2" class="data row2 col2" >4.44</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Policy'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Policy')
# Out:
# Customer_Lifetime_Value per Policy
# <style  type="text/css" >
# #T_f2049348_a3a6_11eb_bb52_acfdcef35164row0_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f2049348_a3a6_11eb_bb52_acfdcef35164row1_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row1_col2{
#             background-color:  #009db0;
#             color:  #000000;
#         }#T_f2049348_a3a6_11eb_bb52_acfdcef35164row2_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row2_col2{
#             background-color:  #0058d3;
#             color:  #f1f1f1;
#         }#T_f2049348_a3a6_11eb_bb52_acfdcef35164row3_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row3_col2{
#             background-color:  #0045dc;
#             color:  #f1f1f1;
#         }#T_f2049348_a3a6_11eb_bb52_acfdcef35164row4_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row4_col2{
#             background-color:  #0025ec;
#             color:  #f1f1f1;
#         }#T_f2049348_a3a6_11eb_bb52_acfdcef35164row5_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row5_col2{
#             background-color:  #0017f4;
#             color:  #f1f1f1;
#         }#T_f2049348_a3a6_11eb_bb52_acfdcef35164row6_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row6_col2,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row7_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row7_col2{
#             background-color:  #0007fc;
#             color:  #f1f1f1;
#         }#T_f2049348_a3a6_11eb_bb52_acfdcef35164row8_col1,#T_f2049348_a3a6_11eb_bb52_acfdcef35164row8_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f2049348_a3a6_11eb_bb52_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Policy</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row0_col0" class="data row0 col0" >Personal L3</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row0_col1" class="data row0 col1" >27,489,921.15</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row0_col2" class="data row0 col2" >37.60</td>
#             </tr>
#             <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row1_col0" class="data row1 col0" >Personal L2</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row1_col1" class="data row1 col1" >17,092,517.62</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row1_col2" class="data row1 col2" >23.38</td>
#             </tr>
#             <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row2_col0" class="data row2 col0" >Personal L1</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row2_col1" class="data row2 col1" >9,907,304.90</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row2_col2" class="data row2 col2" >13.55</td>
#             </tr>
#             <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row3_col0" class="data row3 col0" >Corporate L3</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row3_col1" class="data row3 col1" >7,815,630.07</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row3_col2" class="data row3 col2" >10.69</td>
#             </tr>
#             <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row4_col0" class="data row4 col0" >Corporate L2</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row4_col1" class="data row4 col1" >4,520,628.70</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row4_col2" class="data row4 col2" >6.18</td>
#             </tr>
#             <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row5_col0" class="data row5 col0" >Corporate L1</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row5_col1" class="data row5 col1" >3,042,499.23</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row5_col2" class="data row5 col2" >4.16</td>
#             </tr>
#             <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row6_col0" class="data row6 col0" >Special L2</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row6_col1" class="data row6 col1" >1,365,612.64</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row6_col2" class="data row6 col2" >1.87</td>
#             </tr>
#             <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row7_col0" class="data row7 col0" >Special L3</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row7_col1" class="data row7 col1" >1,333,049.61</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row7_col2" class="data row7 col2" >1.82</td>
#             </tr>
#             <tr>
#                         <th id="T_f2049348_a3a6_11eb_bb52_acfdcef35164level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row8_col0" class="data row8 col0" >Special L1</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row8_col1" class="data row8 col1" >549,962.37</td>
#                         <td id="T_f2049348_a3a6_11eb_bb52_acfdcef35164row8_col2" class="data row8 col2" >0.75</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Renew_Offer_Type'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Renew_Offer_Type')
# Out:
# Customer_Lifetime_Value per Renew_Offer_Type
# <style  type="text/css" >
# #T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row0_col1,#T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row1_col1,#T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row1_col2{
#             background-color:  #0090b7;
#             color:  #000000;
#         }#T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row2_col1,#T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row2_col2{
#             background-color:  #0029eb;
#             color:  #f1f1f1;
#         }#T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row3_col1,#T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row3_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Renew_Offer_Type</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row0_col0" class="data row0 col0" >Offer1</td>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row0_col1" class="data row0 col1" >32,668,985.11</td>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row0_col2" class="data row0 col2" >44.68</td>
#             </tr>
#             <tr>
#                         <th id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row1_col0" class="data row1 col0" >Offer2</td>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row1_col1" class="data row1 col1" >21,642,901.70</td>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row1_col2" class="data row1 col2" >29.60</td>
#             </tr>
#             <tr>
#                         <th id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row2_col0" class="data row2 col0" >Offer3</td>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row2_col1" class="data row2 col1" >11,452,973.49</td>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row2_col2" class="data row2 col2" >15.66</td>
#             </tr>
#             <tr>
#                         <th id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row3_col0" class="data row3 col0" >Offer4</td>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row3_col1" class="data row3 col1" >7,352,266.00</td>
#                         <td id="T_f22d7184_a3a6_11eb_a5d7_acfdcef35164row3_col2" class="data row3 col2" >10.06</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Sales_Channel'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Sales_Channel')
# Out:
# Customer_Lifetime_Value per Sales_Channel
# <style  type="text/css" >
# #T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row0_col1,#T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row1_col1,#T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row1_col2{
#             background-color:  #009bb2;
#             color:  #000000;
#         }#T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row2_col1,#T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row2_col2{
#             background-color:  #003ae2;
#             color:  #f1f1f1;
#         }#T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row3_col1,#T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row3_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sales_Channel</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row0_col0" class="data row0 col0" >Agent</td>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row0_col1" class="data row0 col1" >27,668,955.42</td>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row0_col2" class="data row0 col2" >37.84</td>
#             </tr>
#             <tr>
#                         <th id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row1_col0" class="data row1 col0" >Branch</td>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row1_col1" class="data row1 col1" >20,843,300.35</td>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row1_col2" class="data row1 col2" >28.51</td>
#             </tr>
#             <tr>
#                         <th id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row2_col0" class="data row2 col0" >Call Center</td>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row2_col1" class="data row2 col1" >14,296,651.35</td>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row2_col2" class="data row2 col2" >19.55</td>
#             </tr>
#             <tr>
#                         <th id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row3_col0" class="data row3 col0" >Web</td>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row3_col1" class="data row3 col1" >10,308,219.18</td>
#                         <td id="T_f2516fe9_a3a6_11eb_8c5f_acfdcef35164row3_col2" class="data row3 col2" >14.10</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Vehicle_Class'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Vehicle_Class')
# Out:
# Customer_Lifetime_Value per Vehicle_Class
# <style  type="text/css" >
# #T_f274fb71_a3a6_11eb_b158_acfdcef35164row0_col1,#T_f274fb71_a3a6_11eb_b158_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f274fb71_a3a6_11eb_b158_acfdcef35164row1_col1,#T_f274fb71_a3a6_11eb_b158_acfdcef35164row1_col2{
#             background-color:  #0092b6;
#             color:  #000000;
#         }#T_f274fb71_a3a6_11eb_b158_acfdcef35164row2_col1,#T_f274fb71_a3a6_11eb_b158_acfdcef35164row2_col2{
#             background-color:  #005ad2;
#             color:  #f1f1f1;
#         }#T_f274fb71_a3a6_11eb_b158_acfdcef35164row3_col1,#T_f274fb71_a3a6_11eb_b158_acfdcef35164row3_col2{
#             background-color:  #0016f4;
#             color:  #f1f1f1;
#         }#T_f274fb71_a3a6_11eb_b158_acfdcef35164row4_col1,#T_f274fb71_a3a6_11eb_b158_acfdcef35164row4_col2{
#             background-color:  #0003fe;
#             color:  #f1f1f1;
#         }#T_f274fb71_a3a6_11eb_b158_acfdcef35164row5_col1,#T_f274fb71_a3a6_11eb_b158_acfdcef35164row5_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f274fb71_a3a6_11eb_b158_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Vehicle_Class</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f274fb71_a3a6_11eb_b158_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row0_col0" class="data row0 col0" >Four-Door Car</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row0_col1" class="data row0 col1" >30,645,208.65</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row0_col2" class="data row0 col2" >41.91</td>
#             </tr>
#             <tr>
#                         <th id="T_f274fb71_a3a6_11eb_b158_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row1_col0" class="data row1 col0" >SUV</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row1_col1" class="data row1 col1" >18,756,547.22</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row1_col2" class="data row1 col2" >25.65</td>
#             </tr>
#             <tr>
#                         <th id="T_f274fb71_a3a6_11eb_b158_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row2_col0" class="data row2 col0" >Two-Door Car</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row2_col1" class="data row2 col1" >12,581,563.96</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row2_col2" class="data row2 col2" >17.21</td>
#             </tr>
#             <tr>
#                         <th id="T_f274fb71_a3a6_11eb_b158_acfdcef35164level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row3_col0" class="data row3 col0" >Sports Car</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row3_col1" class="data row3 col1" >5,203,478.84</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row3_col2" class="data row3 col2" >7.12</td>
#             </tr>
#             <tr>
#                         <th id="T_f274fb71_a3a6_11eb_b158_acfdcef35164level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row4_col0" class="data row4 col0" >Luxury SUV</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row4_col1" class="data row4 col1" >3,150,631.84</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row4_col2" class="data row4 col2" >4.31</td>
#             </tr>
#             <tr>
#                         <th id="T_f274fb71_a3a6_11eb_b158_acfdcef35164level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row5_col0" class="data row5 col0" >Luxury Car</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row5_col1" class="data row5 col1" >2,779,695.79</td>
#                         <td id="T_f274fb71_a3a6_11eb_b158_acfdcef35164row5_col2" class="data row5 col2" >3.80</td>
#             </tr>
#     </tbody></table>

# %%
# query and barplot
variable = 'Vehicle_Size'
print('Customer_Lifetime_Value per {}'.format(variable))
query(cat2, col='Vehicle_Size')
# Out:
# Customer_Lifetime_Value per Vehicle_Size
# <style  type="text/css" >
# #T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row0_col1,#T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row0_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row1_col1,#T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row1_col2{
#             background-color:  #0028eb;
#             color:  #f1f1f1;
#         }#T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row2_col1,#T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row2_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Vehicle_Size</th>        <th class="col_heading level0 col1" >Customer_Lifetime_Value</th>        <th class="col_heading level0 col2" >PERCENTAGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row0_col0" class="data row0 col0" >Medsize</td>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row0_col1" class="data row0 col1" >51,717,451.11</td>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row0_col2" class="data row0 col2" >70.73</td>
#             </tr>
#             <tr>
#                         <th id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row1_col0" class="data row1 col0" >Small</td>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row1_col1" class="data row1 col1" >14,262,109.22</td>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row1_col2" class="data row1 col2" >19.51</td>
#             </tr>
#             <tr>
#                         <th id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row2_col0" class="data row2 col0" >Large</td>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row2_col1" class="data row2 col1" >7,137,565.96</td>
#                         <td id="T_f29b32aa_a3a6_11eb_bf7a_acfdcef35164row2_col2" class="data row2 col2" >9.76</td>
#             </tr>
#     </tbody></table>
